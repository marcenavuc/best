# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('Dannye_po_Data_Motiv.xlsx')
df.head()
# Out:
#    SUBS_ID  DATE_CALC  TARIFF_ID  CHARGE  SUPPORT_4G  SUPPORT_3G  \
# 0     1245 2019-07-01      588.0   206.1           0           0
# 1     1245 2019-08-01      588.0   378.9           0           0
# 2     1245 2019-09-01      588.0   328.9           0           0
# 3     1261 2019-07-01      524.0   318.6           0           1
# 4     1261 2019-08-01      524.0   262.3           0           1
#
#    LTE_TRAFF_FLAG  SMS_IN_CNT  SMS_OUT_CNT  CALLS_IN_CNT  CALLS_OUT_CNT  \
# 0             0.0         119           11           400            193
# 1             0.0         125           13           332            215
# 2             0.0          75           15           320            221
# 3             0.0         210           39           109             60
# 4             0.0         309           24            72            122
#
#    LIFE_TIME  DURATION_IN_MIN  DURATION_OUT_MIN  DATA_TRAFFIC_MB  \
# 0     5213.0              448            237.15            16.79
# ...

# %%
df.describe()
# Out:
#             SUBS_ID     TARIFF_ID         CHARGE    SUPPORT_4G    SUPPORT_3G  \
# count  8.929300e+04  89287.000000   89293.000000  89293.000000  89293.000000
# mean   1.156639e+06    315.999048     261.287274      0.601313      0.724939
# std    5.199966e+05    170.092115     785.094780      0.489631      0.446547
# min    1.245000e+03     59.000000       0.000000      0.000000      0.000000
# 25%    7.350280e+05    135.000000      66.600000      0.000000      0.000000
# 50%    1.148620e+06    300.000000     250.000000      1.000000      1.000000
# 75%    1.602853e+06    524.000000     350.000000      1.000000      1.000000
# max    2.069926e+06    610.000000  156138.850000      1.000000      1.000000
#
#        LTE_TRAFF_FLAG    SMS_IN_CNT   SMS_OUT_CNT  CALLS_IN_CNT  \
# count    88682.000000  89293.000000  89293.000000  89293.000000
# mean         0.457387    116.794934     12.423706    102.224822
# std          0.498184    117.619508     55.758458    117.047228
# ...

# %%
# Как не надо делатб
#
#
#
#prep_df = df[['SUBS_ID', 'TARIFF_ID']]
#prep_df.head()
#people_posts = df['SUBS_ID'].value_counts()
#people_posts.head()
#people_posts.values == 3
#indexs = np.where(people_posts.values == 3)[0]
#indexs

# %%
a = []
for i in range(0, df.shape[0]-2):
    if df['SUBS_ID'][i] == df['SUBS_ID'][i + 1] == df['SUBS_ID'][i + 2]:
        a.append(i)
a = np.array(a)
a.shape
# Out:
# (29531,)

# %%
prep = df.loc[a]
prep
# Out:
#        SUBS_ID  DATE_CALC  TARIFF_ID  CHARGE  SUPPORT_4G  SUPPORT_3G  \
# 0         1245 2019-07-01      588.0  206.10           0           0
# 3         1261 2019-07-01      524.0  318.60           0           1
# 6         1325 2019-07-01      130.0  142.19           0           1
# 9         1334 2019-07-01      560.0  300.00           1           1
# 12        1364 2019-07-01      300.0  129.60           0           0
# ...        ...        ...        ...     ...         ...         ...
# 89277  2069541 2019-07-01      300.0  153.60           1           1
# 89280  2069592 2019-07-01      121.0   26.50           1           1
# 89283  2069686 2019-07-01      135.0   32.40           0           0
# 89286  2069822 2019-07-01      560.0  300.00           1           1
# 89289  2069892 2019-07-01      121.0  100.20           1           1
#
#        LTE_TRAFF_FLAG  SMS_IN_CNT  SMS_OUT_CNT  CALLS_IN_CNT  CALLS_OUT_CNT  \
# ...

# %%
prep['SUBS_ID'].value_counts()
# Out:
# 745584     1
# 1954849    1
# 1892017    1
# 1296050    1
# 1046196    1
#           ..
# 1730452    1
# 1240040    1
# 517097     1
# 1295341    1
# 1445890    1
# Name: SUBS_ID, Length: 29531, dtype: int64

# %%
b = []
for i in range(df['SUBS_ID'].values.shape[0]):
    if df['SUBS_ID'][i] in prep['SUBS_ID'].values:
        b.append(i)
b = np.array(b)
b.shape
# Out:
# (88593,)

# %%
three_df = df.iloc[b]
three_df = three_df.reset_index(drop=True)
three_df
# Out:
#        SUBS_ID  DATE_CALC  TARIFF_ID  CHARGE  SUPPORT_4G  SUPPORT_3G  \
# 0         1245 2019-07-01      588.0   206.1           0           0
# 1         1245 2019-08-01      588.0   378.9           0           0
# 2         1245 2019-09-01      588.0   328.9           0           0
# 3         1261 2019-07-01      524.0   318.6           0           1
# 4         1261 2019-08-01      524.0   262.3           0           1
# ...        ...        ...        ...     ...         ...         ...
# 88588  2069822 2019-08-01      560.0   306.0           1           1
# 88589  2069822 2019-09-01      560.0   300.0           1           1
# 88590  2069892 2019-07-01      121.0   100.2           1           1
# 88591  2069892 2019-08-01      121.0   135.0           1           1
# 88592  2069892 2019-09-01      121.0   181.6           1           1
#
#        LTE_TRAFF_FLAG  SMS_IN_CNT  SMS_OUT_CNT  CALLS_IN_CNT  CALLS_OUT_CNT  \
# ...

# %%
track = []
for row_id in range(0, three_df.shape[0], 3):
    isis = three_df['TARIFF_ID'][row_id] == three_df['TARIFF_ID'][row_id + 1] == three_df['TARIFF_ID'][row_id + 2]
    for j in range(3):
        track.append(isis)
track = pd.Series(track)

# %%
three_df['Y'] = track

# %%
three_df['Y'].value_counts()
# Out:
# True     85500
# False     3093
# Name: Y, dtype: int64

# %%
_ = pd.read_excel('Data_Motiv_2.xlsx')
_
# Out:
#        SUBS_ID  DATE_CALC  TARIFF_ID  CHARGE  SUPPORT_4G  SUPPORT_3G  \
# 0         1197 2019-07-01        NaN  300.00           1           1
# 1         1197 2019-08-01        NaN  250.00           1           1
# 2         1197 2019-09-01        NaN  252.00           1           1
# 3         1205 2019-07-01        NaN  121.90           0           1
# 4         1205 2019-08-01        NaN  175.60           1           1
# ...        ...        ...        ...     ...         ...         ...
# 90702  2069907 2019-08-01        NaN   63.00           0           1
# 90703  2069907 2019-09-01        NaN   43.20           0           1
# 90704  2069917 2019-07-01        NaN  161.08           0           1
# 90705  2069917 2019-08-01        NaN  212.88           0           1
# 90706  2069917 2019-09-01        NaN  178.40           0           1
#
#        LTE_TRAFF_FLAG  SMS_IN_CNT  SMS_OUT_CNT  CALLS_IN_CNT  CALLS_OUT_CNT  \
# ...
